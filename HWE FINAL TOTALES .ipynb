# %%
import pandas as pd
import numpy as np

# %%
rs17599586 = pd.read_csv("1000genomesprojectphase3-PopulationGenotypes-Homo_sapiens_Variation_Population_rs17599586.csv")
rs2295644 = pd.read_csv("1000genomesprojectphase3-PopulationGenotypes-Homo_sapiens_Variation_Population_rs2295644.csv")
rs10483801 = pd.read_csv("1000genomesprojectphase3-PopulationGenotypes-Homo_sapiens_Variation_Population_rs10483801.csv")
rs2182008 = pd.read_csv("1000genomesprojectphase3-PopulationGenotypes-Homo_sapiens_Variation_Population_rs2182008.csv")
rs9319428 = pd.read_csv("1000genomesprojectphase3-PopulationGenotypes-Homo_sapiens_Variation_Population_rs9319428.csv")
rs3751395 = pd.read_csv("1000genomesprojectphase3-PopulationGenotypes-Homo_sapiens_Variation_Population_rs3751395.csv")
rs2387634 = pd.read_csv("1000genomesprojectphase3-PopulationGenotypes-Homo_sapiens_Variation_Population_rs2387634.csv")
rs10494225 = pd.read_csv("1000genomesprojectphase3-PopulationGenotypes-Homo_sapiens_Variation_Population_rs10494225.csv")
rs7977109 = pd.read_csv("1000genomesprojectphase3-PopulationGenotypes-Homo_sapiens_Variation_Population_rs7977109.csv")
rs816361 = pd.read_csv("1000genomesprojectphase3-PopulationGenotypes-Homo_sapiens_Variation_Population_rs816361.csv")
rs7309163 = pd.read_csv("1000genomesprojectphase3-PopulationGenotypes-Homo_sapiens_Variation_Population_rs7309163.csv")
rs5006884 = pd.read_csv("1000genomesprojectphase3-PopulationGenotypes-Homo_sapiens_Variation_Population_rs5006884.csv")
rs8002446 = pd.read_csv("1000genomesprojectphase3-PopulationGenotypes-Homo_sapiens_Variation_Population_rs8002446.csv")
rs826729 = pd.read_csv("1000genomesprojectphase3-PopulationGenotypes-Homo_sapiens_Variation_Population_rs826729.csv")
rs765587 = pd.read_csv("1000genomesprojectphase3-PopulationGenotypes-Homo_sapiens_Variation_Population_rs765587.csv")
rs9693712 = pd.read_csv("1000genomesprojectphase3-PopulationGenotypes-Homo_sapiens_Variation_Population_rs9693712.csv")
rs172652 = pd.read_csv("1000genomesprojectphase3-PopulationGenotypes-Homo_sapiens_Variation_Population_rs172652.csv")
rs380620 = pd.read_csv("1000genomesprojectphase3-PopulationGenotypes-Homo_sapiens_Variation_Population_rs380620.csv")
rs2693430 = pd.read_csv("1000genomesprojectphase3-PopulationGenotypes-Homo_sapiens_Variation_Population_rs2693430.csv")
rs12155519 = pd.read_csv("1000genomesprojectphase3-PopulationGenotypes-Homo_sapiens_Variation_Population_rs12155519.csv")

rs28384513 = pd.read_csv("1000genomesprojectphase3-PopulationGenotypes-Homo_sapiens_Variation_Population_rs28384513.csv", sep =",")
rs9402686 = pd.read_csv("1000genomesprojectphase3-PopulationGenotypes-Homo_sapiens_Variation_Population_rs9402686.csv")
rs9399137 = pd.read_csv("1000genomesprojectphase3-PopulationGenotypes-Homo_sapiens_Variation_Population_rs9399137.csv")
rs4895441 = pd.read_csv("1000genomesprojectphase3-PopulationGenotypes-Homo_sapiens_Variation_Population_rs4895441.csv")
rs7581162 = pd.read_csv("1000genomesprojectphase3-PopulationGenotypes-Homo_sapiens_Variation_Population_rs7581162.csv")
rs10189857 = pd.read_csv("1000genomesprojectphase3-PopulationGenotypes-Homo_sapiens_Variation_Population_rs10189857.csv")
rs1427407 = pd.read_csv("1000genomesprojectphase3-PopulationGenotypes-Homo_sapiens_Variation_Population_rs1427407.csv")
rs7599488 = pd.read_csv("1000genomesprojectphase3-PopulationGenotypes-Homo_sapiens_Variation_Population_rs7599488.csv")
rs766432 = pd.read_csv("1000genomesprojectphase3-PopulationGenotypes-Homo_sapiens_Variation_Population_rs766432.csv")
rs11886868 = pd.read_csv("1000genomesprojectphase3-PopulationGenotypes-Homo_sapiens_Variation_Population_rs11886868.csv")
rs4671393 = pd.read_csv("1000genomesprojectphase3-PopulationGenotypes-Homo_sapiens_Variation_Population_rs4671393.csv")
rs7557939 = pd.read_csv("1000genomesprojectphase3-PopulationGenotypes-Homo_sapiens_Variation_Population_rs7557939.csv")
rs10184550 = pd.read_csv("1000genomesprojectphase3-PopulationGenotypes-Homo_sapiens_Variation_Population_rs10184550.csv")
rs10128556 = pd.read_csv("1000genomesprojectphase3-PopulationGenotypes-Homo_sapiens_Variation_Population_rs10128556.csv")
rs2310991 = pd.read_csv("1000genomesprojectphase3-PopulationGenotypes-Homo_sapiens_Variation_Population_rs2310991.csv")
rs61743453 = pd.read_csv("1000genomesprojectphase3-PopulationGenotypes-Homo_sapiens_Variation_Population_rs61743453.csv")

rs334 = pd.read_csv("1000genomesprojectphase3-PopulationGenotypes-Homo_sapiens_Variation_Population_rs334.csv")

# %%
snp = ["rs17599586",
"rs2295644",
"rs10483801",
"rs2182008",
"rs9319428",
"rs3751395",
"rs2387634",
"rs10494225",
"rs7977109",
"rs816361",
"rs7309163",
"rs5006884",
"rs8002446",
"rs826729",
"rs765587",
"rs9693712",
"rs172652",
"rs380620",
"rs2693430",
"rs12155519",
'rs28384513',
'rs9402686',
'rs9399137',
'rs4895441',
'rs7581162',
'rs10189857',
'rs1427407',
'rs7599488',
'rs766432',
'rs11886868',
'rs4671393',
'rs7557939',
'rs10184550',
'rs10128556',
'rs2310991',
'rs61743453', 
      "rs334"]

# %%
len(snp)
# Out:
# 37

# %%
rs17599586["snp"] = "rs17599586" 
rs2295644["snp"] = "rs2295644"
rs10483801["snp"] = "rs10483801"
rs2182008["snp"] = "rs2182008"
rs9319428["snp"] = "rs9319428"
rs3751395["snp"] = "rs3751395"
rs2387634["snp"] = "rs2387634"
rs10494225["snp"] = "rs10494225"
rs7977109["snp"] = "rs7977109"
rs816361["snp"] = "rs816361"
rs7309163["snp"] = "rs7309163"
rs5006884["snp"] = "rs5006884"
rs8002446["snp"] = "rs8002446"
rs826729["snp"] = "rs826729"
rs765587["snp"] = "rs765587"
rs9693712["snp"] = "rs9693712"
rs172652["snp"] = "rs172652"
rs380620["snp"] = "rs380620"
rs2693430["snp"] = "rs2693430"
rs12155519["snp"] = "rs12155519"



rs28384513["snp"] = "rs28384513"
rs9402686["snp"] = "rs9402686"
rs9399137["snp"] = "rs9399137"
rs4895441["snp"] = "rs4895441"
rs7581162["snp"] = "rs7581162"
rs10189857["snp"] = "rs10189857"
rs1427407["snp"] = "rs1427407"
rs7599488["snp"] = "rs7599488"
rs766432["snp"] = "rs766432"
rs11886868["snp"] = "rs11886868"
rs4671393["snp"] = "rs4671393"
rs7557939["snp"] = "rs7557939"
rs10184550["snp"] = "rs10184550"
rs10128556["snp"] = "rs10128556"
rs2310991["snp"] = "rs2310991"
rs61743453["snp"] = "rs61743453"

rs334["snp"] = "rs334"

# %%
df_all = pd.concat((rs17599586,
rs2295644,
rs10483801,
rs2182008,
rs9319428,
rs3751395,
rs2387634,
rs10494225,
rs7977109,
rs816361,
rs7309163,
rs5006884,
rs8002446,
rs826729,
rs765587,
rs9693712,
rs172652,
rs380620,
rs2693430,
rs12155519, 
rs28384513, 
rs9402686, 
rs9399137,
rs4895441, 
rs7581162, 
rs10189857, 
rs1427407,
rs7599488,
rs766432,
rs11886868, 
rs4671393, 
rs7557939, 
rs10184550, 
rs10128556,
rs2310991, 
rs61743453, 
rs334), axis = 0)

# %%
new_cols = df_all["Population"].str.split(";", expand = True)

# In[40]:

new_cols

# In[41]:

df_all = pd.concat((df_all, new_cols), axis = 1)

# %%
df_all
# Out:
#                        Population  Unnamed: 1  \
# 0     ALL;1000GENOMES:phase_3:ALL         NaN
# 1     AFR;1000GENOMES:phase_3:AFR         NaN
# 2     ACB;1000GENOMES:phase_3:ACB         NaN
# 3     ASW;1000GENOMES:phase_3:ASW         NaN
# 4     ESN;1000GENOMES:phase_3:ESN         NaN
# ..                            ...         ...
# 27    BEB;1000GENOMES:phase_3:BEB         NaN
# 28    GIH;1000GENOMES:phase_3:GIH         NaN
# 29    ITU;1000GENOMES:phase_3:ITU         NaN
# 30    PJL;1000GENOMES:phase_3:PJL         NaN
# 31    STU;1000GENOMES:phase_3:STU         NaN
#
#           Allele: frequency (count)  \
# 0   C: 0.913 (4574) T: 0.087 (434)
# 1   C: 0.883 (1167) T: 0.117 (155)
# 2     C: 0.891 (171) T: 0.109 (21)
# 3     C: 0.893 (109) T: 0.107 (13)
# 4     C: 0.879 (174) T: 0.121 (24)
# ..                              ...
# 27                  T: 1.000 (172)
# 28                  T: 1.000 (206)
# 29                  T: 1.000 (204)
# 30                  T: 1.000 (192)
# ...

# %%
df_all = df_all.drop(["Population", 1, "Unnamed: 1",
"Genotypes"], axis = 1 )



genotype = df_all["Genotype: frequency (count)"].str.split(" ", expand= True)


cols_geno = {0:"homocygoto_1", 1:"frecuencia_g_1",
2:"ndeind_g_1",
3:"homocygoto_2", 4:"frecuencia_g_2",
5:"ndeind_g_2",
6:"heterocygoto", 7:"frecuencia_g_3",
8:"ndeind_g_3", 9:"?"}


genotype = genotype.rename(columns = cols_geno)

# %%
genotype
# Out:
#    homocygoto_1 frecuencia_g_1 ndeind_g_1 homocygoto_2 frecuencia_g_2  \
# 0          C|C:          0.837     (2095)         C|T:          0.153
# 1          C|C:          0.781      (516)         C|T:          0.204
# 2          C|C:          0.781       (75)         C|T:          0.219
# 3          C|C:          0.787       (48)         C|T:          0.213
# 4          C|C:          0.778       (77)         C|T:          0.202
# ..          ...            ...        ...          ...            ...
# 27         T|T:          1.000       (86)                        None
# 28         T|T:          1.000      (103)                        None
# 29         T|T:          1.000      (102)                        None
# 30         T|T:          1.000       (96)                        None
# 31         T|T:          1.000      (102)                        None
#
#    ndeind_g_2 heterocygoto frecuencia_g_3 ndeind_g_3     ?
# 0       (384)         T|T:          0.010       (25)
# ...

# %%
allele_frec = df_all["Allele: frequency (count)"].str.split(" ", expand= True)


cols_allele = {0:"alelo_1", 1:"frecuencia_a_1", 2:"ndeind_a_1",
3:"alelo_2", 4:"frecuencia_a_2", 5:"ndeind_a_2",
6:"?"}

# %%
allele_frec = allele_frec.rename(columns = cols_allele)

# %%
allele_frec
# Out:
#    alelo_1 frecuencia_a_1 ndeind_a_1 alelo_2 frecuencia_a_2 ndeind_a_2     ?
# 0       C:          0.913     (4574)      T:          0.087      (434)
# 1       C:          0.883     (1167)      T:          0.117      (155)
# 2       C:          0.891      (171)      T:          0.109       (21)
# 3       C:          0.893      (109)      T:          0.107       (13)
# 4       C:          0.879      (174)      T:          0.121       (24)
# ..     ...            ...        ...     ...            ...        ...   ...
# 27      T:          1.000      (172)                   None       None  None
# 28      T:          1.000      (206)                   None       None  None
# 29      T:          1.000      (204)                   None       None  None
# 30      T:          1.000      (192)                   None       None  None
# 31      T:          1.000      (204)                   None       None  None
#
# [1184 rows x 7 columns]

# %%
# In[52]:

df_all= pd.concat((df_all, genotype, allele_frec),
axis=1)

# In[53]:

df_all = df_all.drop(["Allele: frequency (count)",
"Genotype: frequency (count)"], axis = 1)

# %%
df_all = df_all.rename(columns = {0:'Population'})

# In[56]:

df_all = df_all.drop(["?"], axis = 1 )

# %%
#borrar :
df_all["homocygoto_1"] = df_all["homocygoto_1"].str.replace(':', '')
df_all["homocygoto_2"] = df_all["homocygoto_2"].str.replace(':', '')
df_all["heterocygoto"] = df_all["heterocygoto"].str.replace(':', '')
df_all["alelo_1"] = df_all["alelo_1"].str.replace(':','')
df_all["alelo_2"] = df_all["alelo_2"].str.replace(':', '')

# In[58]:

#borrar ()
df_all["ndeind_g_1"] = df_all["ndeind_g_1"].str.replace('(', '')
df_all["ndeind_g_1"] = df_all["ndeind_g_1"].str.replace(')', '')
df_all["ndeind_g_2"] = df_all["ndeind_g_2"].str.replace('(', '')
df_all["ndeind_g_2"] = df_all["ndeind_g_2"].str.replace(')', '')
df_all["ndeind_g_3"] = df_all["ndeind_g_3"].str.replace('(', '')
df_all["ndeind_g_3"] = df_all["ndeind_g_3"].str.replace(')', '')

df_all["ndeind_a_1"] = df_all["ndeind_a_1"].str.replace('(', '')
df_all["ndeind_a_1"] = df_all["ndeind_a_1"].str.replace(')', '')
df_all["ndeind_a_2"] = df_all["ndeind_a_2"].str.replace('(', '')
df_all["ndeind_a_2"] = df_all["ndeind_a_2"].str.replace(')', '')

# %%
df_all
# Out:
#            snp Population homocygoto_1 frecuencia_g_1 ndeind_g_1 homocygoto_2  \
# 0   rs17599586        ALL          C|C          0.837       2095          C|T
# 1   rs17599586        AFR          C|C          0.781        516          C|T
# 2   rs17599586        ACB          C|C          0.781         75          C|T
# 3   rs17599586        ASW          C|C          0.787         48          C|T
# 4   rs17599586        ESN          C|C          0.778         77          C|T
# ..         ...        ...          ...            ...        ...          ...
# 27       rs334        BEB          T|T          1.000         86
# 28       rs334        GIH          T|T          1.000        103
# 29       rs334        ITU          T|T          1.000        102
# 30       rs334        PJL          T|T          1.000         96
# 31       rs334        STU          T|T          1.000        102
#
#    frecuencia_g_2 ndeind_g_2 heterocygoto frecuencia_g_3 ndeind_g_3 alelo_1  \
# ...

# %%
#lista poblaciones principales
pop = ["ALL", "AFR", "AMR", "EAS", "EUR", "SAS"]


#nuevo dataframe seleccionando solo la informacion de las poblaciones enlistadas en pop
#df_all = df_all.loc[df.Population=="ALL"]
df_afr = df_all.loc[df_all.Population=="AFR"]
df_amr = df_all.loc[df_all.Population=="AMR"]
df_eas = df_all.loc[df_all.Population=="EAS"]
df_eur = df_all.loc[df_all.Population=="EUR"]
df_sas = df_all.loc[df_all.Population=="SAS"]
df_pop = pd.concat((df_afr, df_amr, df_eas, df_eur, df_sas))

# %%
df_pop = df_pop.fillna(0)

# %%
df_pop.dtypes
# Out:
# snp               object
# Population        object
# homocygoto_1      object
# frecuencia_g_1    object
# ndeind_g_1        object
# homocygoto_2      object
# frecuencia_g_2    object
# ndeind_g_2        object
# heterocygoto      object
# frecuencia_g_3    object
# ndeind_g_3        object
# alelo_1           object
# frecuencia_a_1    object
# ndeind_a_1        object
# alelo_2           object
# frecuencia_a_2    object
# ndeind_a_2        object
# dtype: object

# %%
df_pop["ndeind_g_1"] = df_pop["ndeind_g_1"].apply(float)
df_pop["ndeind_a_1"] = df_pop["ndeind_a_1"].apply(float)

# %%
## hacer una nueva columna con los snp y cambiar manualmente el efecto fisiologico
df_pop['descripcion'] = df_pop["snp"]

# %%
df_pop['descripcion'].replace('rs17599586', 'HbF change, %',inplace=True)
df_pop['descripcion'].replace('rs2295644', 'HbF change, %',inplace=True)
df_pop['descripcion'].replace('rs10483801', 'HbF and HbF response to hydroxyurea',inplace=True)
df_pop['descripcion'].replace('rs2182008', 'HbF and HbF response to hydroxyurea',inplace=True)
df_pop['descripcion'].replace('rs9319428', 'HbF and HbF response to hydroxyurea',inplace=True)
df_pop['descripcion'].replace('rs3751395', 'HbF and HbF response to hydroxyurea',inplace=True)
df_pop['descripcion'].replace('rs2387634', 'HbF and HbF response to hydroxyurea',inplace=True)
df_pop['descripcion'].replace('rs10494225', 'HbF and HbF response to hydroxyurea',inplace=True)
df_pop['descripcion'].replace('rs7977109', 'HbF and HbF response to hydroxyurea',inplace=True)
df_pop['descripcion'].replace('rs816361', 'HbF and HbF response to hydroxyurea',inplace=True)
df_pop['descripcion'].replace('rs7309163', 'HbF and HbF response to hydroxyurea',inplace=True)
df_pop['descripcion'].replace('rs5006884', 'Regulation of HbA2 level',inplace=True)
df_pop['descripcion'].replace('rs8002446', 'HbF and HbF response to hydroxyurea',inplace=True)
df_pop['descripcion'].replace('rs826729', 'HbF and HbF response to hydroxyurea',inplace=True)
df_pop['descripcion'].replace('rs765587', 'HbF and HbF response to hydroxyurea',inplace=True)
df_pop['descripcion'].replace('rs9693712', 'HbF and HbF response to hydroxyurea',inplace=True)
df_pop['descripcion'].replace('rs172652', 'HbF and HbF response to hydroxyurea',inplace=True)
df_pop['descripcion'].replace('rs380620', 'HbF and HbF response to hydroxyurea',inplace=True)
df_pop['descripcion'].replace('rs2693430', 'HbF and HbF response to hydroxyurea',inplace=True)
df_pop['descripcion'].replace('rs12155519', 'HbF and HbF response to hydroxyurea',inplace=True)


df_pop['descripcion'].replace('rs28384513', 'Basal Levels of HBF',inplace=True)
df_pop['descripcion'].replace('rs9402686', 'Basal Levels of HBF',inplace=True)
df_pop['descripcion'].replace('rs9399137', 'Basal Levels of HBF',inplace=True)
df_pop['descripcion'].replace('rs4895441', 'Basal Levels of HBF',inplace=True)
df_pop['descripcion'].replace('rs7581162', 'Basal Levels of HBF',inplace=True)
df_pop['descripcion'].replace('rs10189857', 'Basal Levels of HBF',inplace=True)
df_pop['descripcion'].replace('rs1427407', 'Basal Levels of HBF',inplace=True)
df_pop['descripcion'].replace('rs7599488', 'Basal Levels of HBF',inplace=True)
df_pop['descripcion'].replace('rs766432', 'Basal Levels of HBF',inplace=True)
df_pop['descripcion'].replace('rs11886868', 'Basal Levels of HBF',inplace=True)
df_pop['descripcion'].replace('rs4671393', 'Basal Levels of HBF',inplace=True)
df_pop['descripcion'].replace('rs7557939', 'Basal Levels of HBF',inplace=True)
df_pop['descripcion'].replace('rs10184550', 'Basal Levels of HBF',inplace=True)
df_pop['descripcion'].replace('rs10128556', 'Basal Levels of HBF',inplace=True)
df_pop['descripcion'].replace('rs2310991', 'HBF levels in response to Hydroxyurea treatment',inplace=True)
df_pop['descripcion'].replace('rs61743453', 'HBF levels in response to Hydroxyurea treatment',inplace=True)
df_pop['descripcion'].replace('rs334', 'sickle cell anemia',inplace=True)

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import plotly.express as px

import scipy.stats as ss
from numpy import random

# %%
 hwcols = {'snp':'snp', 'Population':'Population',
'homocygoto_1':'pp', 'frecuencia_g_1':'frecuencia_pp',
'ndeind_g_1':'ndeind_pp',
'homocygoto_2':'qq', 'frecuencia_g_2':'frecuencia_qq',
'ndeind_g_2':'ndeind_qq', 'heterocygoto':'2pq',
'frecuencia_g_3':'frecuencia_2pq',
'ndeind_g_3':'ndeind_2pq', 'alelo_1':'p',
'frecuencia_a_1':'frecuencia_p',
'ndeind_a_1':'ndeind_p', 'alelo_2':'q',
'frecuencia_a_2':'frecuencia_q', 'ndeind_a_2':'ndeind_q',
'descripcion':'descripcion'}

# %%
# Calculo de frecuencias esperadas
df_pop.rename(columns = hwcols, inplace= True )

# %%
df_pop
# Out:
#            snp Population   pp frecuencia_pp  ndeind_pp   qq frecuencia_qq  \
# 1   rs17599586        AFR  C|C         0.781      516.0  C|T         0.204
# 1    rs2295644        AFR  A|A         0.411      272.0  A|T         0.469
# 1   rs10483801        AFR  C|C         0.325      215.0  A|A         0.165
# 1    rs2182008        AFR  A|A         0.024       16.0  A|G         0.234
# 1    rs9319428        AFR  G|G         0.496      328.0  A|A         0.116
# ..         ...        ...  ...           ...        ...  ...           ...
# 26  rs10184550        SAS  G|G         0.405      198.0  A|A         0.108
# 26  rs10128556        SAS  C|C         0.552      270.0  C|T         0.376
# 26   rs2310991        SAS  C|C         0.405      198.0  A|A         0.151
# 26  rs61743453        SAS  G|G         1.000      489.0                  0
# 26       rs334        SAS  T|T         1.000      489.0                  0
#
# ...

# %%
df_pop.dtypes
# Out:
# snp                object
# Population         object
# pp                 object
# frecuencia_pp      object
# ndeind_pp         float64
# qq                 object
# frecuencia_qq      object
# ndeind_qq          object
# 2pq                object
# frecuencia_2pq     object
# ndeind_2pq         object
# p                  object
# frecuencia_p       object
# ndeind_p          float64
# q                  object
# frecuencia_q       object
# ndeind_q           object
# descripcion        object
# dtype: object

# %%
df_pop["frecuencia_pp"] = df_pop["frecuencia_pp"].apply(float)
df_pop["frecuencia_qq"] = df_pop["frecuencia_qq"].apply(float)

df_pop["ndeind_qq"] = df_pop["ndeind_qq"].apply(float)
df_pop["frecuencia_2pq"] = df_pop["frecuencia_2pq"].apply(float)

df_pop["ndeind_2pq"] = df_pop["ndeind_2pq"].apply(float)
df_pop["ndeind_2pq"] = df_pop["ndeind_2pq"].apply(float)

df_pop["frecuencia_p"] = df_pop["frecuencia_p"].apply(float)
df_pop["frecuencia_q"] = df_pop["frecuencia_q"].apply(float)

df_pop["ndeind_q"] = df_pop["ndeind_q"].apply(float)

# %%
# In[143]:

df_pop["total_ind_ob"] = df_pop["ndeind_pp"] + df_pop["ndeind_qq"] + df_pop["ndeind_2pq"]


# In[144]:

df_pop["p_esperada"] = (2*df_pop["ndeind_pp"] + df_pop["ndeind_2pq"])/(2*df_pop["total_ind_ob"])

# In[145]:

df_pop["q_esperada"] = (2*df_pop["ndeind_qq"]+ df_pop["ndeind_2pq"])/(2*df_pop["total_ind_ob"])

# In[146]:

df_pop["pp_esperada"] = df_pop["p_esperada"]*df_pop["p_esperada"]*df_pop["total_ind_ob"]

# In[147]:

df_pop["pq_esperada"]= 2*df_pop["p_esperada"]*df_pop["q_esperada"]*df_pop["total_ind_ob"]

# In[148]:

df_pop["qq_esperada"]= df_pop["q_esperada"]*df_pop["q_esperada"]*df_pop["total_ind_ob"]

# In[149]:

df_pop["total_ind_esp"] = df_pop["pp_esperada"]+ df_pop["qq_esperada"] + df_pop["pq_esperada"]

# %%
df_pop["pp_esperada"] = df_pop["pp_esperada"].apply(int)
df_pop["pq_esperada"] = df_pop["pq_esperada"].apply(int)
df_pop["qq_esperada"] = df_pop["qq_esperada"].apply(int)
df_pop["total_ind_ob"] = df_pop["total_ind_ob"].apply(int)
df_pop["total_ind_esp"] = df_pop["total_ind_esp"].apply(int)
df_pop["ndeind_pp"] = df_pop["ndeind_pp"].apply(int)
df_pop["ndeind_qq"] = df_pop["ndeind_qq"].apply(int)
df_pop["ndeind_2pq"] = df_pop["ndeind_2pq"].apply(int)

# %%
df_pop["total_ind_ob"] == df_pop["total_ind_esp"]
# Out:
# 1      True
# 1      True
# 1      True
# 1      True
# 1      True
#       ...
# 26     True
# 26     True
# 26    False
# 26     True
# 26     True
# Length: 185, dtype: bool

# %%
import pandas as pd
import numpy as np
import scipy.stats as ss
from numpy import random
from scipy.stats import chi2_contingency
from scipy.stats import chisquare

# %%
df_pop[["snp", "p"]].head(16)
# Out:
#           snp  p
# 1  rs17599586  C
# 1   rs2295644  A
# 1  rs10483801  C
# 1   rs2182008  A
# 1   rs9319428  G
# 1   rs3751395  C
# 1   rs2387634  T
# 1  rs10494225  C
# 1   rs7977109  G
# 1    rs816361  C
# 1   rs7309163  C
# 1   rs5006884  C
# 1   rs8002446  G
# 1    rs826729  G
# 1    rs765587  T
# 1   rs9693712  C

# %%
df_pop.dtypes
# Out:
# snp                object
# Population         object
# pp                 object
# frecuencia_pp     float64
# ndeind_pp           int64
# qq                 object
# frecuencia_qq     float64
# ndeind_qq           int64
# 2pq                object
# frecuencia_2pq    float64
# ndeind_2pq          int64
# p                  object
# frecuencia_p      float64
# ndeind_p          float64
# q                  object
# frecuencia_q      float64
# ndeind_q          float64
# descripcion        object
# total_ind_ob        int64
# p_esperada        float64
# q_esperada        float64
# pp_esperada         int64
# pq_esperada         int64
# qq_esperada         int64
# total_ind_esp       int64
# dtype: object

# %%
df_pop[["ndeind_pp", "ndeind_2pq", "ndeind_qq","pp_esperada",
"pq_esperada", "qq_esperada", "total_ind_esp", "total_ind_ob"]]
# Out:
#     ndeind_pp  ndeind_2pq  ndeind_qq  pp_esperada  pq_esperada  qq_esperada  \
# 1         516          10        135          410          220           29
# 1         272          79        310          146          329          184
# 1         215         337        109          222          322          116
# 1          16         490        155          103          315          242
# 1         328         256         77          314          282           63
# ..        ...         ...        ...          ...          ...          ...
# 26        198         238         53          205          223           60
# 26        270          35        184          169          236           83
# 26        198         217         74          192          228           68
# 26        489           0          0          489            0            0
# 26        489           0          0          489            0            0
#
#     total_ind_esp  total_ind_ob
# ...

# %%
chisquare(df_pop[["ndeind_pp", "ndeind_2pq", "ndeind_qq"]][0:1],
f_exp = df_pop[["pp_esperada", "pq_esperada", "qq_esperada"]]
[0:1], axis = 1)
# Out:
# Power_divergenceResult(statistic=array([615.30769937]), pvalue=array([2.44135394e-134]))

# %%
df_pop[["ndeind_pp", "ndeind_2pq", "ndeind_qq"]][0:1]
# Out:
#    ndeind_pp  ndeind_2pq  ndeind_qq
# 1        516          10        135

# %%
rango = range(0,185)

print(rango)
# Out:
# range(0, 185)

# %%
#Calculo de HWE
for n in rango:
    chi_v = print(chisquare(df_pop[["ndeind_pp", "ndeind_2pq", "ndeind_qq"]][n:(n+1)],
                            f_exp = df_pop[["pp_esperada", "pq_esperada", "qq_esperada"]][n:(n+1)], ddof = 0, axis = 1)[1])
# Out:
# [2.44135394e-134]
# [2.51224812e-84]
# [0.51122466]
# [1.37917402e-44]
1.40109696e-68,
3.0675238e-07,
1.4138418e-41,
0.09726513,
0.96315607,
0.99452056,
0.99457996,
2.13332873e-101,
0.82911474,
0.02988125,
0.85016402,
0.07804996,
0.8634263,
1.90626829e-46,
1.19317146e-39,
0.99789252,
0.35617616,
1.07404573e-77,
0.53590051,
"nan",
"nan"]

# %%
df_pop["chi_value"] = chi2_value
df_pop["p_value"] = p_value

# %%
df_pop["chi_value"] = df_pop["chi_value"].apply(float)


df_pop["p_value"] = df_pop["p_value"].apply(float)

# %%
significativo = []
for i in df_pop.p_value:
    if i < 0.05:
        significativo.append("si")
    elif i > 0.05:
        significativo.append("no")
    else:
        significativo.append("nan")

# In[116]:

df_pop["significativo"] = significativo

# %%
df_pop
# Out:
#            snp Population   pp  frecuencia_pp  ndeind_pp   qq  frecuencia_qq  \
# 1   rs17599586        AFR  C|C          0.781        516  C|T          0.204
# 1    rs2295644        AFR  A|A          0.411        272  A|T          0.469
# 1   rs10483801        AFR  C|C          0.325        215  A|A          0.165
# 1    rs2182008        AFR  A|A          0.024         16  A|G          0.234
# 1    rs9319428        AFR  G|G          0.496        328  A|A          0.116
# ..         ...        ...  ...            ...        ...  ...            ...
# 26  rs10184550        SAS  G|G          0.405        198  A|A          0.108
# 26  rs10128556        SAS  C|C          0.552        270  C|T          0.376
# 26   rs2310991        SAS  C|C          0.405        198  A|A          0.151
# 26  rs61743453        SAS  G|G          1.000        489               0.000
# 26       rs334        SAS  T|T          1.000        489               0.000
#
# ...

# %%
df_yes = df_pop[df_pop['significativo'] == "si"]

# %%
df_yes[["snp", "Population", "descripcion", "chi_value", "p_value"]].sort_values("snp").to_excel("df_yes_hwe.xlsx")

# %%
len(df_yes["snp"].unique())
# Out:
# 23

# %%
df_yes_AFR  = df_yes[df_yes['Population'] == "AFR"]
df_yes_AMR  = df_yes[df_yes['Population'] == "AMR"]
df_yes_EAS  = df_yes[df_yes['Population'] == "EAS"]
df_yes_EUR  = df_yes[df_yes['Population'] == "EUR"]
df_yes_SAS  = df_yes[df_yes['Population'] == "SAS"]

# %%
df_yes_AFR[["snp", "descripcion", "chi_value", "p_value"]]
# Out:
#           snp                                      descripcion   chi_value  \
# 1  rs17599586                                    HbF change, %  615.307699
# 1   rs2295644                                    HbF change, %  384.991940
# 1   rs2182008              HbF and HbF response to hydroxyurea  201.984519
# 1   rs9319428              HbF and HbF response to hydroxyurea    6.132478
# 1  rs10494225              HbF and HbF response to hydroxyurea  448.238743
# 1    rs816361              HbF and HbF response to hydroxyurea  508.655731
# 1   rs7309163              HbF and HbF response to hydroxyurea   44.292078
# 1   rs5006884                         Regulation of HbA2 level  407.608217
# 1   rs9693712              HbF and HbF response to hydroxyurea  470.822350
# 1    rs172652              HbF and HbF response to hydroxyurea   49.541669
# 1    rs380620              HbF and HbF response to hydroxyurea  248.480473
# ...

# %%
df_yes_AMR[["snp", "descripcion", "chi_value", "p_value"]]
# Out:
#           snp                                      descripcion   chi_value  \
# 9  rs17599586                                    HbF change, %  356.732951
# 9   rs2295644                                    HbF change, %  201.163177
# 9   rs2182008              HbF and HbF response to hydroxyurea  283.949124
# 9  rs10494225              HbF and HbF response to hydroxyurea  327.208475
# 9    rs816361              HbF and HbF response to hydroxyurea  251.526531
# 9   rs7309163              HbF and HbF response to hydroxyurea  225.010958
# 9   rs5006884                         Regulation of HbA2 level  268.478883
# 9   rs9693712              HbF and HbF response to hydroxyurea  104.695005
# 9    rs172652              HbF and HbF response to hydroxyurea  171.109377
# 9    rs380620              HbF and HbF response to hydroxyurea  106.034481
# 9   rs2693430              HbF and HbF response to hydroxyurea  227.969535
# ...

# %%
df_yes_EAS[["snp", "descripcion", "chi_value", "p_value"]]
# Out:
#            snp                                      descripcion   chi_value  \
# 14  rs17599586                                    HbF change, %         inf
# 14   rs2295644                                    HbF change, %  252.716699
# 14   rs2387634              HbF and HbF response to hydroxyurea         inf
# 14  rs10494225              HbF and HbF response to hydroxyurea  528.240385
# 14    rs816361              HbF and HbF response to hydroxyurea  316.472206
# 14   rs7309163              HbF and HbF response to hydroxyurea  272.721713
# 14   rs5006884                         Regulation of HbA2 level  461.049809
# 14   rs9693712              HbF and HbF response to hydroxyurea  323.136173
# 14    rs172652              HbF and HbF response to hydroxyurea         inf
# 14   rs2693430              HbF and HbF response to hydroxyurea  235.442593
# 14   rs4895441                              Basal Levels of HBF  351.435791
# ...

# %%
df_yes_EUR[["snp", "descripcion", "chi_value", "p_value"]]
# Out:
#            snp                          descripcion   chi_value        p_value
# 20  rs17599586                        HbF change, %  481.960074  2.206479e-105
# 20   rs2295644                        HbF change, %  224.686566   1.621556e-49
# 20   rs2182008  HbF and HbF response to hydroxyurea         inf   0.000000e+00
# 20  rs10494225  HbF and HbF response to hydroxyurea  517.480635  4.270788e-113
# 20    rs816361  HbF and HbF response to hydroxyurea  339.256722   2.144563e-74
# 20   rs7309163  HbF and HbF response to hydroxyurea  268.959515   3.946239e-59
# 20   rs5006884             Regulation of HbA2 level  372.531191   1.276085e-81
# 20   rs9693712  HbF and HbF response to hydroxyurea   13.899783   9.587400e-04
# 20    rs172652  HbF and HbF response to hydroxyurea  207.136771   1.049112e-45
# 20    rs380620  HbF and HbF response to hydroxyurea   53.551731   2.351740e-12
# 20   rs2693430  HbF and HbF response to hydroxyurea  369.157524   6.893856e-81
# ...

# %%
df_yes_SAS[["snp", "descripcion", "chi_value", "p_value"]]
# Out:
#            snp                          descripcion   chi_value        p_value
# 26  rs17599586                        HbF change, %  477.665723  1.888888e-104
# 26   rs2295644                        HbF change, %  205.886485   1.960279e-45
# 26   rs2182008  HbF and HbF response to hydroxyurea         inf   0.000000e+00
# 26  rs10494225  HbF and HbF response to hydroxyurea  432.274884   1.357380e-94
# 26    rs816361  HbF and HbF response to hydroxyurea  378.662444   5.949699e-83
# 26   rs7309163  HbF and HbF response to hydroxyurea  234.620302   1.129403e-51
# 26   rs5006884             Regulation of HbA2 level  354.624913   9.866849e-78
# 26   rs9693712  HbF and HbF response to hydroxyurea   48.718584   2.635688e-11
# 26    rs172652  HbF and HbF response to hydroxyurea  312.477062   1.401097e-68
# 26    rs380620  HbF and HbF response to hydroxyurea   29.994450   3.067524e-07
# 26   rs2693430  HbF and HbF response to hydroxyurea  188.119356   1.413842e-41
# ...
